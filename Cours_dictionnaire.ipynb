# %% [markdown]
# # I.<b><u>Qu'est-ce un dictionnaire</b></u>?
#
# <b><u>Important</u></b>...

# %% [markdown]
# <u>Exemple </u> :
# ````Python
# dico1={"nom":"Durand","prenom":"Christophe","date de naissance":"29/01/2001"}
# ````
#
# Nous utilisons les…………………………... {} pour définir le début et la fin du dictionnaire (alors que nous utilisons des crochets [ ] pour les tableaux et des parenthèses ( ) pour les tuples).
#
# Dans le dictionnaire ci-dessus, …

# %% [markdown]
# La clé "nom" est associée à la valeur "Durand", la clé "prenom" est associée à la valeur "Christophe" et
# la clé "date de naissance" est associée à la valeur "29/01/2001".
#
# <b><u>Important</u></b>...

# %% [markdown]
# * Les valeurs peuvent être des chaînes de caractères, des booléens....
#
# * Le dictionnaire est une représentation en Python d'une fonction (au sens mathématique) qui a une clé associe une valeur.
#                         f : {"nom", "prenom", "date de naissance"} →  {chaînes de caractères}
#
#                                                              "nom"   |→  "Durand"
#
#                                                           "prenom"   |→  "Christophe"
#
#                                                 "date de naissance"  |→  "29/01/2001"
#
# <u>Application 1</u> : La variable dico1 référence un dictionnaire.
# Il est possible d’afficher le contenu du dictionnaire référencé par la variable dico1 en saisissant dico1 dans la console.
# Faites le test après avoir exécuté le programme ci-dessous.
# ````Python
# dico1={"nom":"Durand","prenom":"Christophe","date de naissance":"29/01/2001"}
# ````

# %% [markdown]
# <u>Remarques</u>: * Contrairement aux chaînes de caractères, aux tableaux et aux tuples, les dictionnaires ...

# %% [markdown]
# * Les dictionnaires sont appelés aussi tuples nommés.
#    En Python, les dictionnaires sont de type dict.
#
# # II. <b><u>Accès aux éléments d'un dictionnaire</u></b>.
#
# <b><u>Important</u></b>: ...

# %% [markdown]
# <b><u> Application 2</u></b>: Tester dans la console :
# ````Python
# dico1["nom"]
# dico1["date de naissance"]
# dico1["Durand"]
# ````

# %% [markdown]
# <b><u>Conséquence</u></b> :...

# %% [markdown]
# <b><u>Important</u></b> : Comme pour les chaînes de caractères, tableaux et tuples, il est aussi possible de demander

# %% [markdown]
# <b><u> Application 3</u></b> : Tester dans la console :
# ````Python
# "nom" in dico1
# "Lieu de naissance" in dico1
# ````

# %% [markdown]
# # III. <b><u> Modification d’un dictionnaire</u></b>.
#
# <b><u> Important </u></b> :...

# %% [markdown]
# <b><u>Remarque</u></b> :  En général, les tuples nommés ne sont pas mutables dans les langages de programmation.
# Le langage Python se démarque donc avec ses dictionnaires mutables.

# %% [markdown]
# <b><u> Application 4</u></b> : Quel est le contenu du dictionnaire référencé par la variable "mes_fruits" après l’exécution
# des programme ci-dessus ? Vérifiez votre réponse à l’aide de la console.
# ````Python
# mes_fruits={"poires":3,"pommes":4,"oranges":2}
# mes_fruits["pommes"]=8
# ````

# %% [markdown]
# ````Python
# mes_fruits={"poires":3,"pommes":4,"oranges":2}
# mes_fruits["citrons"]=2
# ````

# %% [markdown]
# ````Python
# mes_fruits={"poires":3,"pommes":4,"oranges":2}
# del mes_fruits["pommes"]
# ````

# %% [markdown]
# # IV. <b><u> Comment construire un dictionnaire </u></b> ?

# %% [markdown]
# ````Python
# dico1={"nom":"Durand","prenom":"Christophe","date de naissance":"29/01/2001"}
# ````

# %% [markdown]
# <u>Exemples</u> :Créer le dictionnaire en compréhension contenant pour les clés, les nombres entiers de 2 à 10 inclus, et pour les valeurs associées, le cube de la clé.

# %% [markdown]
# # V. <b><u>Parcours d'un dictionnaire : Voir les clés ou/et les valeurs.</u></b>.
#
# <b> Important </b> :omme les chaînes de caractères, tableaux et tuples, les dictionnaires sont itérables.
# Il est ainsi …

# %% [markdown]
# Ce parcours peut se faire selon les clés ou/et les valeurs.
#
# * Commençons par ... à l’aide de la ………………………….
#
# <u>Application 4</u> : Tester le programme suivant :
# ````Python
# mes_fruits={"poires":3,"pommes":4,"oranges":2}
# print ("Liste des fruits")
# for fruit in mes_fruits.keys():
#     print(fruit)
# ````

# %% [markdown]
# La méthode ....
#
# <u>Applications 5</u> :
# ````Python
# mes_fruits={"poires":3,"pommes":4,"oranges":2}
# for qte in mes_fruits.values():
#     print(qte)
# ````

# %% [markdown]
# * Enfin, il est possible de ...

# %% [markdown]
# <u>Applications 6</u> :
# ````Python
# mes_fruits={"poires":3,"pommes":4,"oranges":2}
# print ("Stock de fruits")
# for frui,qtet in mes_fruits.items():
#     print(fruit,qte)
# ````

# %% [markdown]
# <u>Remarque</u> : On a utilisé le ...

# %% [markdown]
# # V. <b><u>Applications directes</u></b>.
#
# <b><u>Exercice 1</u></b> :
# La variable contacts ci-dessous contient une liste de contacts d’un smartphone.
# Cette liste de contacts est stockée à l’aide d’un dictionnaire Python.
# ````Python
# contacts={'Chloé':'0601020304','Quentin':'0710203040','Sophie':'0623344556','Alex':'0423345678'}
# ````
#
# 1. Qu’affiche print(contacts.keys()) ?
# 2. Qu’affiche print(contacts.values()) ?
# 3. Quelle instruction permet de remplacer le numéro de Chloé par ’0611223344’ ?
# 4. Quelle instruction permet d’ajouter Sarah dans la liste de contacts, dont le numéro est 0145444342 ?
# 5. Quelle instruction permet d’afficher le numéro de Sophie ?
# 6. Quelle instruction permet d’effacer Chloé du répertoire ?

# %% [markdown]
# <b><u>Exercice 2</u></b> :
# Ecrire une fonction inverse_tab_contacts qui prend en argument une liste de contacts comme dans l’exercice
# précédent et qui renvoie le tableau indexé par les numéros au lieu des noms.
# Par exemple, inverse_tab_contacts(contacts) renverra :
# [Voir feuille d'exercices](dico10.png!)
